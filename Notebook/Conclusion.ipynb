# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('Saved Data/best_measure1_V1', 'rb') as f:
    best_measure_1_1 = pickle.load(f)
with open('Saved Data/best_measure1_V3', 'rb') as f:
    best_measure_1_3 = pickle.load(f)
with open('Saved Data/best_measure3_V1', 'rb') as f:
    best_measure_3_1 = pickle.load(f)
with open('Saved Data/best_measure3_V3', 'rb') as f:
    best_measure_3_3 = pickle.load(f)

# %%
plt.plot(np.linspace(0,1,11),best_measure_1_1,label = "Preprocessing 1 - V1")
plt.plot(np.linspace(0,1,11),best_measure_1_3,label = "Preprocessing 1 - V3")
plt.plot(np.linspace(0,1,11),best_measure_3_1,label = "Preprocessing 3 - V1")
plt.plot(np.linspace(0,1,11),best_measure_3_3,label = "Preprocessing 3 - V3")
plt.legend() 
plt.title("Comparaison between preprocessing and version with JSD")
plt.show()
